# %% [markdown]
# # Examples
#
# This page contains a few examples of how you can use AI Uncovered package.
#
# ## Installation
#
# You can install AI Uncovered using `pip`:

# %%
pip install aibasics
# Out:
# Requirement already satisfied: aibasics in /opt/hostedtoolcache/Python/3.11.4/x64/lib/python3.11/site-packages (0.0.0)
# Requirement already satisfied: click<9.0.0,>=8.1.3 in /opt/hostedtoolcache/Python/3.11.4/x64/lib/python3.11/site-packages (from aibasics) (8.1.6)
# Requirement already satisfied: hyfi<2.0.0,>=1.12.5 in /opt/hostedtoolcache/Python/3.11.4/x64/lib/python3.11/site-packages (from aibasics) (1.12.5)
# Requirement already satisfied: chardet<=5.1.0 in /opt/hostedtoolcache/Python/3.11.4/x64/lib/python3.11/site-packages (from hyfi<2.0.0,>=1.12.5->aibasics) (5.1.0)
# Requirement already satisfied: colorama<0.5.0,>=0.4.3 in /opt/hostedtoolcache/Python/3.11.4/x64/lib/python3.11/site-packages (from hyfi<2.0.0,>=1.12.5->aibasics) (0.4.6)
# Requirement already satisfied: datasets<=2.14.1,>=2.0.0 in /opt/hostedtoolcache/Python/3.11.4/x64/lib/python3.11/site-packages (from hyfi<2.0.0,>=1.12.5->aibasics) (2.14.1)
# Requirement already satisfied: filelock<=3.12.2,>=3.4 in /opt/hostedtoolcache/Python/3.11.4/x64/lib/python3.11/site-packages (from hyfi<2.0.0,>=1.12.5->aibasics) (3.12.2)
# Requirement already satisfied: gdown<=4.6.6 in /opt/hostedtoolcache/Python/3.11.4/x64/lib/python3.11/site-packages (from hyfi<2.0.0,>=1.12.5->aibasics) (4.6.6)
# Requirement already satisfied: huggingface-hub<=0.16.4,>=0.8.1 in /opt/hostedtoolcache/Python/3.11.4/x64/lib/python3.11/site-packages (from hyfi<2.0.0,>=1.12.5->aibasics) (0.16.4)
# Requirement already satisfied: hydra-colorlog<2.0.0,>=1.2.0 in /opt/hostedtoolcache/Python/3.11.4/x64/lib/python3.11/site-packages (from hyfi<2.0.0,>=1.12.5->aibasics) (1.2.0)
# Requirement already satisfied: hydra-core<2.0.0,>=1.3.2 in /opt/hostedtoolcache/Python/3.11.4/x64/lib/python3.11/site-packages (from hyfi<2.0.0,>=1.12.5->aibasics) (1.3.2)
# Requirement already satisfied: joblib<2.0.0,>=1.3.1 in /opt/hostedtoolcache/Python/3.11.4/x64/lib/python3.11/site-packages (from hyfi<2.0.0,>=1.12.5->aibasics) (1.3.1)
# Requirement already satisfied: matplotlib<4.0.0,>=3.7.1 in /opt/hostedtoolcache/Python/3.11.4/x64/lib/python3.11/site-packages (from hyfi<2.0.0,>=1.12.5->aibasics) (3.7.2)
# Requirement already satisfied: numpy<=1.24.4 in /opt/hostedtoolcache/Python/3.11.4/x64/lib/python3.11/site-packages (from hyfi<2.0.0,>=1.12.5->aibasics) (1.24.4)
# Requirement already satisfied: pandas<=2.0.3,>=1.5.3 in /opt/hostedtoolcache/Python/3.11.4/x64/lib/python3.11/site-packages (from hyfi<2.0.0,>=1.12.5->aibasics) (2.0.3)
# Requirement already satisfied: pathspec>=0.9.0 in /opt/hostedtoolcache/Python/3.11.4/x64/lib/python3.11/site-packages (from hyfi<2.0.0,>=1.12.5->aibasics) (0.11.2)
# Requirement already satisfied: pyarrow<=12.0.1 in /opt/hostedtoolcache/Python/3.11.4/x64/lib/python3.11/site-packages (from hyfi<2.0.0,>=1.12.5->aibasics) (12.0.1)
# Requirement already satisfied: pydantic<3.0.0,>=2.1.1 in /opt/hostedtoolcache/Python/3.11.4/x64/lib/python3.11/site-packages (from hyfi<2.0.0,>=1.12.5->aibasics) (2.1.1)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.0.1 in /opt/hostedtoolcache/Python/3.11.4/x64/lib/python3.11/site-packages (from hyfi<2.0.0,>=1.12.5->aibasics) (2.0.2)
# Requirement already satisfied: python-dotenv<2.0.0,>=1.0.0 in /opt/hostedtoolcache/Python/3.11.4/x64/lib/python3.11/site-packages (from hyfi<2.0.0,>=1.12.5->aibasics) (1.0.0)
# Requirement already satisfied: requests<3.0.0,>=2.27.1 in /opt/hostedtoolcache/Python/3.11.4/x64/lib/python3.11/site-packages (from hyfi<2.0.0,>=1.12.5->aibasics) (2.31.0)
# Requirement already satisfied: rich<14.0,>=12.1 in /opt/hostedtoolcache/Python/3.11.4/x64/lib/python3.11/site-packages (from hyfi<2.0.0,>=1.12.5->aibasics) (13.5.0)
# Requirement already satisfied: scipy<2.0.0,>=1.10.1 in /opt/hostedtoolcache/Python/3.11.4/x64/lib/python3.11/site-packages (from hyfi<2.0.0,>=1.12.5->aibasics) (1.11.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.64.1 in /opt/hostedtoolcache/Python/3.11.4/x64/lib/python3.11/site-packages (from hyfi<2.0.0,>=1.12.5->aibasics) (4.65.0)
# Requirement already satisfied: dill<0.3.8,>=0.3.0 in /opt/hostedtoolcache/Python/3.11.4/x64/lib/python3.11/site-packages (from datasets<=2.14.1,>=2.0.0->hyfi<2.0.0,>=1.12.5->aibasics) (0.3.7)
# Requirement already satisfied: xxhash in /opt/hostedtoolcache/Python/3.11.4/x64/lib/python3.11/site-packages (from datasets<=2.14.1,>=2.0.0->hyfi<2.0.0,>=1.12.5->aibasics) (3.3.0)
# Requirement already satisfied: multiprocess in /opt/hostedtoolcache/Python/3.11.4/x64/lib/python3.11/site-packages (from datasets<=2.14.1,>=2.0.0->hyfi<2.0.0,>=1.12.5->aibasics) (0.70.15)
# Requirement already satisfied: fsspec[http]>=2021.11.1 in /opt/hostedtoolcache/Python/3.11.4/x64/lib/python3.11/site-packages (from datasets<=2.14.1,>=2.0.0->hyfi<2.0.0,>=1.12.5->aibasics) (2023.6.0)
# Requirement already satisfied: aiohttp in /opt/hostedtoolcache/Python/3.11.4/x64/lib/python3.11/site-packages (from datasets<=2.14.1,>=2.0.0->hyfi<2.0.0,>=1.12.5->aibasics) (3.8.5)
# Requirement already satisfied: packaging in /opt/hostedtoolcache/Python/3.11.4/x64/lib/python3.11/site-packages (from datasets<=2.14.1,>=2.0.0->hyfi<2.0.0,>=1.12.5->aibasics) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in /opt/hostedtoolcache/Python/3.11.4/x64/lib/python3.11/site-packages (from datasets<=2.14.1,>=2.0.0->hyfi<2.0.0,>=1.12.5->aibasics) (6.0.1)
# Requirement already satisfied: six in /opt/hostedtoolcache/Python/3.11.4/x64/lib/python3.11/site-packages (from gdown<=4.6.6->hyfi<2.0.0,>=1.12.5->aibasics) (1.16.0)
# Requirement already satisfied: beautifulsoup4 in /opt/hostedtoolcache/Python/3.11.4/x64/lib/python3.11/site-packages (from gdown<=4.6.6->hyfi<2.0.0,>=1.12.5->aibasics) (4.12.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /opt/hostedtoolcache/Python/3.11.4/x64/lib/python3.11/site-packages (from huggingface-hub<=0.16.4,>=0.8.1->hyfi<2.0.0,>=1.12.5->aibasics) (4.7.1)
# Requirement already satisfied: colorlog in /opt/hostedtoolcache/Python/3.11.4/x64/lib/python3.11/site-packages (from hydra-colorlog<2.0.0,>=1.2.0->hyfi<2.0.0,>=1.12.5->aibasics) (6.7.0)
# Requirement already satisfied: omegaconf<2.4,>=2.2 in /opt/hostedtoolcache/Python/3.11.4/x64/lib/python3.11/site-packages (from hydra-core<2.0.0,>=1.3.2->hyfi<2.0.0,>=1.12.5->aibasics) (2.3.0)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in /opt/hostedtoolcache/Python/3.11.4/x64/lib/python3.11/site-packages (from hydra-core<2.0.0,>=1.3.2->hyfi<2.0.0,>=1.12.5->aibasics) (4.9.3)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/hostedtoolcache/Python/3.11.4/x64/lib/python3.11/site-packages (from matplotlib<4.0.0,>=3.7.1->hyfi<2.0.0,>=1.12.5->aibasics) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /opt/hostedtoolcache/Python/3.11.4/x64/lib/python3.11/site-packages (from matplotlib<4.0.0,>=3.7.1->hyfi<2.0.0,>=1.12.5->aibasics) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/hostedtoolcache/Python/3.11.4/x64/lib/python3.11/site-packages (from matplotlib<4.0.0,>=3.7.1->hyfi<2.0.0,>=1.12.5->aibasics) (4.41.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/hostedtoolcache/Python/3.11.4/x64/lib/python3.11/site-packages (from matplotlib<4.0.0,>=3.7.1->hyfi<2.0.0,>=1.12.5->aibasics) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in /opt/hostedtoolcache/Python/3.11.4/x64/lib/python3.11/site-packages (from matplotlib<4.0.0,>=3.7.1->hyfi<2.0.0,>=1.12.5->aibasics) (10.0.0)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in /opt/hostedtoolcache/Python/3.11.4/x64/lib/python3.11/site-packages (from matplotlib<4.0.0,>=3.7.1->hyfi<2.0.0,>=1.12.5->aibasics) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/hostedtoolcache/Python/3.11.4/x64/lib/python3.11/site-packages (from matplotlib<4.0.0,>=3.7.1->hyfi<2.0.0,>=1.12.5->aibasics) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/hostedtoolcache/Python/3.11.4/x64/lib/python3.11/site-packages (from pandas<=2.0.3,>=1.5.3->hyfi<2.0.0,>=1.12.5->aibasics) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in /opt/hostedtoolcache/Python/3.11.4/x64/lib/python3.11/site-packages (from pandas<=2.0.3,>=1.5.3->hyfi<2.0.0,>=1.12.5->aibasics) (2023.3)
# Requirement already satisfied: annotated-types>=0.4.0 in /opt/hostedtoolcache/Python/3.11.4/x64/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.1.1->hyfi<2.0.0,>=1.12.5->aibasics) (0.5.0)
# Requirement already satisfied: pydantic-core==2.4.0 in /opt/hostedtoolcache/Python/3.11.4/x64/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.1.1->hyfi<2.0.0,>=1.12.5->aibasics) (2.4.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/hostedtoolcache/Python/3.11.4/x64/lib/python3.11/site-packages (from requests<3.0.0,>=2.27.1->hyfi<2.0.0,>=1.12.5->aibasics) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/hostedtoolcache/Python/3.11.4/x64/lib/python3.11/site-packages (from requests<3.0.0,>=2.27.1->hyfi<2.0.0,>=1.12.5->aibasics) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/hostedtoolcache/Python/3.11.4/x64/lib/python3.11/site-packages (from requests<3.0.0,>=2.27.1->hyfi<2.0.0,>=1.12.5->aibasics) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/hostedtoolcache/Python/3.11.4/x64/lib/python3.11/site-packages (from requests<3.0.0,>=2.27.1->hyfi<2.0.0,>=1.12.5->aibasics) (2023.7.22)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /opt/hostedtoolcache/Python/3.11.4/x64/lib/python3.11/site-packages (from rich<14.0,>=12.1->hyfi<2.0.0,>=1.12.5->aibasics) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/hostedtoolcache/Python/3.11.4/x64/lib/python3.11/site-packages (from rich<14.0,>=12.1->hyfi<2.0.0,>=1.12.5->aibasics) (2.15.1)
# Requirement already satisfied: attrs>=17.3.0 in /opt/hostedtoolcache/Python/3.11.4/x64/lib/python3.11/site-packages (from aiohttp->datasets<=2.14.1,>=2.0.0->hyfi<2.0.0,>=1.12.5->aibasics) (23.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/hostedtoolcache/Python/3.11.4/x64/lib/python3.11/site-packages (from aiohttp->datasets<=2.14.1,>=2.0.0->hyfi<2.0.0,>=1.12.5->aibasics) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /opt/hostedtoolcache/Python/3.11.4/x64/lib/python3.11/site-packages (from aiohttp->datasets<=2.14.1,>=2.0.0->hyfi<2.0.0,>=1.12.5->aibasics) (4.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in /opt/hostedtoolcache/Python/3.11.4/x64/lib/python3.11/site-packages (from aiohttp->datasets<=2.14.1,>=2.0.0->hyfi<2.0.0,>=1.12.5->aibasics) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/hostedtoolcache/Python/3.11.4/x64/lib/python3.11/site-packages (from aiohttp->datasets<=2.14.1,>=2.0.0->hyfi<2.0.0,>=1.12.5->aibasics) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/hostedtoolcache/Python/3.11.4/x64/lib/python3.11/site-packages (from aiohttp->datasets<=2.14.1,>=2.0.0->hyfi<2.0.0,>=1.12.5->aibasics) (1.3.1)
# Requirement already satisfied: mdurl~=0.1 in /opt/hostedtoolcache/Python/3.11.4/x64/lib/python3.11/site-packages (from markdown-it-py>=2.2.0->rich<14.0,>=12.1->hyfi<2.0.0,>=1.12.5->aibasics) (0.1.2)
# Requirement already satisfied: soupsieve>1.2 in /opt/hostedtoolcache/Python/3.11.4/x64/lib/python3.11/site-packages (from beautifulsoup4->gdown<=4.6.6->hyfi<2.0.0,>=1.12.5->aibasics) (2.4.1)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /opt/hostedtoolcache/Python/3.11.4/x64/lib/python3.11/site-packages (from requests<3.0.0,>=2.27.1->hyfi<2.0.0,>=1.12.5->aibasics) (1.7.1)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Usage
#
# ```python
# from aibasics import get_version
#
# print(get_version())
# ```
